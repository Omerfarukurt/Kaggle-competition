# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv('train.csv')

# %%
data.head(30)
# Out:
#                datetime  season  holiday  workingday  weather   temp   atemp  \
# 0   2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1   2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2   2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3   2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4   2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5   2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6   2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7   2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8   2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9   2011-01-01 09:00:00       1        0           0        1  13.12  17.425
# 10  2011-01-01 10:00:00       1        0           0        1  15.58  19.695
# ...

# %%
df=data.copy()

# %%
df['datetime']=pd.to_datetime(df['datetime'])

# %%
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df['hour']=df['datetime'].dt.hour

# %%
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  hour
# 0        81        0.0       3          13     16     0
# 1        80        0.0       8          32     40     1
# 2        80        0.0       5          27     32     2
# 3        75        0.0       3          10     13     3
# 4        75        0.0       0           1      1     4

# %%
df['month']=df['datetime'].dt.month

# %%
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  hour  month
# 0        81        0.0       3          13     16     0      1
# 1        80        0.0       8          32     40     1      1
# 2        80        0.0       5          27     32     2      1
# 3        75        0.0       3          10     13     3      1
# 4        75        0.0       0           1      1     4      1

# %%
df.month.value_counts()
# Out:
# month
# 5     912
# 6     912
# 7     912
# 8     912
# 12    912
# 10    911
# 11    911
# 4     909
# 9     909
# 2     901
# 3     901
# 1     884
# Name: count, dtype: int64

# %%
df.drop(['registered','casual'],axis=1,inplace=True)

# %%
df.drop('datetime',axis=1,inplace=True)

# %%
df.head(25)
# Out:
#     season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0        1        0           0        1   9.84  14.395        81     0.0000
# 1        1        0           0        1   9.02  13.635        80     0.0000
# 2        1        0           0        1   9.02  13.635        80     0.0000
# 3        1        0           0        1   9.84  14.395        75     0.0000
# 4        1        0           0        1   9.84  14.395        75     0.0000
# 5        1        0           0        2   9.84  12.880        75     6.0032
# 6        1        0           0        1   9.02  13.635        80     0.0000
# 7        1        0           0        1   8.20  12.880        86     0.0000
# 8        1        0           0        1   9.84  14.395        75     0.0000
# 9        1        0           0        1  13.12  17.425        76     0.0000
# 10       1        0           0        1  15.58  19.695        76    16.9979
# ...

# %%
plt.figure(figsize=(8,8))
sns.histplot(data=df, x='month', discrete=True)  # discrete=True aylara tam sayılar olarak davranır

plt.xlabel('Ay')
plt.ylabel('İşlem Sayısı (Count)')
plt.title('Aya Göre İşlem Sayısı')
plt.show()

# %%
monthly_counts = df.groupby('month')['count'].sum().reset_index()

# Çubuk grafik çiz
sns.barplot(data=monthly_counts, x='month', y='count')
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %% [markdown]
# BURDA GÖRÜNENE GÖRE 5.AYDAN 10.AYA KADAR YANİ İLK VE SONBAHAR AYLARINDA KİRALAMA ORANI ARTMAYA BAŞLAMIŞ

# %%
group_season=df.groupby('season')['count'].sum().reset_index()

# %%
sns.barplot(data=group_season,x='season',y='count')
# Out:
# <Axes: xlabel='season', ylabel='count'>

# %% [markdown]
# BURDAKİ VERİLERE GÖREDE KIŞIN KİRALANAN SAYI İLKBAHARI GEÇMİŞ      //1->İLKBAHAR   2->YAZ   3->SONBAHAR   4->KIŞ

# %%
sns.histplot(data=df, x='month', hue='season', multiple='stack', discrete=True)
plt.show()

# %%
sns.histplot(data=df,x=df['count'],hue=df['workingday'],kde=True,palette='Set1')
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
sns.scatterplot(data=df, x='temp', y='count', alpha=0.5)
# Out:
# <Axes: xlabel='temp', ylabel='count'>

# %%
sns.scatterplot(data=df, x='windspeed', y='count', alpha=0.5)
# Out:
# <Axes: xlabel='windspeed', ylabel='count'>

# %%
df.isnull().sum()
# Out:
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# count         0
# hour          0
# month         0
# dtype: int64

# %%
df.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    count  hour  month
# 0     16     0      1
# 1     40     1      1
# 2     32     2      1
# 3     13     3      1
# 4      1     4      1

# %%
X=df.drop('count',axis=1)
y=df['count']

# %%
col_name=X.columns

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df['hour_sin'] = np.sin(2 * np.pi * df['hour'] / 24)
df['hour_cos'] = np.cos(2 * np.pi * df['hour'] / 24)

df['month_sin'] = np.sin(2 * np.pi * df['month'] / 12)
df['month_cos'] = np.cos(2 * np.pi * df['month'] / 12)

# %%
df.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    count  hour  month  hour_sin  hour_cos  month_sin  month_cos
# 0     16     0      1  0.000000  1.000000        0.5   0.866025
# 1     40     1      1  0.258819  0.965926        0.5   0.866025
# 2     32     2      1  0.500000  0.866025        0.5   0.866025
# 3     13     3      1  0.707107  0.707107        0.5   0.866025
# 4      1     4      1  0.866025  0.500000        0.5   0.866025

# %%
df.drop(['hour','month'],axis=1,inplace=True)

# %%
X=df.drop('count',axis=1)

# %%
X.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    hour_sin  hour_cos  month_sin  month_cos
# 0  0.000000  1.000000        0.5   0.866025
# 1  0.258819  0.965926        0.5   0.866025
# 2  0.500000  0.866025        0.5   0.866025
# 3  0.707107  0.707107        0.5   0.866025
# 4  0.866025  0.500000        0.5   0.866025

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
dtr=DecisionTreeRegressor(max_depth=30,random_state=42,min_samples_split=10)

# %%
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=30, min_samples_split=10, random_state=42)

# %%
y_pred_dtr=dtr.predict(X_test)

# %%
from sklearn.metrics import root_mean_squared_error,r2_score,mean_absolute_error

# %%
root_mean_squared_error(y_test,y_pred_dtr)
# Out:
# 84.79932325097624

# %%
r2_score(y_test,y_pred_dtr)
# Out:
# 0.7821389645731782

# %%
mean_absolute_error(y_test,y_pred_dtr)
# Out:
# 54.59535506580961

# %%
test_df=pd.read_csv('test.csv')

# %%
test_df.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
test_df['datetime']=pd.to_datetime(test_df['datetime'])

# %%
test_df['hour']=test_df['datetime'].dt.hour
test_df['month']=test_df['datetime'].dt.month

# %%
test_df['hour_sin'] = np.sin(2 * np.pi * test_df['hour'] / 24)
test_df['hour_cos'] = np.cos(2 * np.pi * test_df['hour'] / 24)

test_df['month_sin'] = np.sin(2 * np.pi * test_df['month'] / 12)
test_df['month_cos'] = np.cos(2 * np.pi * test_df['month'] / 12)

# %%
test_df.head()
# Out:
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  hour  month  hour_sin  hour_cos  month_sin  month_cos
# 0        56    26.0027     0      1  0.000000  1.000000        0.5   0.866025
# 1        56     0.0000     1      1  0.258819  0.965926        0.5   0.866025
# 2        56     0.0000     2      1  0.500000  0.866025        0.5   0.866025
# 3        56    11.0014     3      1  0.707107  0.707107        0.5   0.866025
# 4        56    11.0014     4      1  0.866025  0.500000        0.5   0.866025

# %%
test_df.drop(['datetime','hour','month'],axis=1,inplace=True)

# %%
test_df.head()
# Out:
#    season  holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0       1        0           1        1  10.66  11.365        56    26.0027
# 1       1        0           1        1  10.66  13.635        56     0.0000
# 2       1        0           1        1  10.66  13.635        56     0.0000
# 3       1        0           1        1  10.66  12.880        56    11.0014
# 4       1        0           1        1  10.66  12.880        56    11.0014
#
#    hour_sin  hour_cos  month_sin  month_cos
# 0  0.000000  1.000000        0.5   0.866025
# 1  0.258819  0.965926        0.5   0.866025
# 2  0.500000  0.866025        0.5   0.866025
# 3  0.707107  0.707107        0.5   0.866025
# 4  0.866025  0.500000        0.5   0.866025

# %%
X.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    hour_sin  hour_cos  month_sin  month_cos
# 0  0.000000  1.000000        0.5   0.866025
# 1  0.258819  0.965926        0.5   0.866025
# 2  0.500000  0.866025        0.5   0.866025
# 3  0.707107  0.707107        0.5   0.866025
# 4  0.866025  0.500000        0.5   0.866025

# %%
y_pred_test=dtr.predict(test_df)

# %%
testdf2=pd.read_csv('test.csv')

# %%
testdf2.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
ids=testdf2['datetime']

# %%
submission=pd.DataFrame({
    "datetime":ids,
    "count":y_pred_test
})

# %%
submission.to_csv("submission.csv",index=False)
